# %%
import keras
import datetime
import tensorflow                       as tf
from tensorflow.keras.callbacks         import TensorBoard
from tensorflow.keras.layers            import Input, Lambda,UpSampling2D, Conv2D,Dropout,MaxPooling2D,Conv2DTranspose,concatenate,BatchNormalization, Activation
from tensorflow.keras.models            import Model
from tensorflow.keras.optimizers        import Adam,RMSprop
from keras.utils                        import plot_model
from tensorflow.keras                   import layers, models
from tensorflow.keras.losses            import mae
import sys
import os
import numpy as np
import math
import random, time
from pathlib                        import Path
from PIL                            import Image

import skimage                      as ski
from   skimage.filters              import threshold_otsu
from   skimage                      import io, color
from   skimage.color                import rgb2gray
from   skimage                      import filters
import cv2                          as cv
import matplotlib.pyplot            as plt 
import gc
import glob
from skimage                        import img_as_ubyte
from skimage                        import io
import shutil
tf.keras.backend.clear_session()
# Out:
# 2025-05-19 22:39:27.261125: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-19 22:39:27.371486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-19 22:39:27.425596: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-19 22:39:27.441750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#pwd='/home/guiomar/Desktop/CODES/Generation_Data/Proyecto_UNI/Pression/p_00013.png' 
#pwd = '/home/guiomar/Desktop/CODES/Generation_Data/Proyecto_UNI/Magnitude/v_19997.png'  
pwd = '/home/guiomar/Desktop/CODES/Generation_Data/Proyecto_UNI/U001/v_x_19950.png'
#pwd = '/home/guiomar/Desktop/CODES/Generation_Data/Proyecto_UNI/U002/v_y_00014.png'
#pwd='/home/guiomar/Desktop/CODES/Generation_Data/Proyecto_UNI/Geometry/geo_00016.png'
def get_img(img_name):
    return ski.io.imread(img_name)

# %%
x=get_img(pwd)
print(x.shape)
plt.imshow(x,cmap='gray')
# Out:
# (185, 737, 3)

# %%
height=x.shape[0]
width=x.shape[1]

aspect_ratio = width / height
# Nuevo alto deseado
new_height = 65
new_width = int(new_height * aspect_ratio)

# %%
y =cv.resize(x,(new_width,new_height))
print(y.shape)
plt.imshow(y,cmap='gray')
# Out:
# (65, 258, 3)

# %%
height=x.shape[0]
width=x.shape[1]

aspect_ratio = height / width


# Nuevo alto deseado
new_width = 200

new_height = int(new_width * aspect_ratio)

y =cv.resize(x,(new_width,new_height))
print(y.shape)
plt.imshow(y,cmap='gray')
# Out:
# (50, 200, 3)
