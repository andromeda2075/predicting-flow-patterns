# %%
import keras
import datetime
import tensorflow                       as tf
from tensorflow.keras.callbacks         import TensorBoard
from tensorflow.keras.layers            import Input, Lambda,UpSampling2D, Conv2D,Dropout,MaxPooling2D,Conv2DTranspose,concatenate,BatchNormalization, Activation
from tensorflow.keras.models            import Model
from tensorflow.keras.optimizers        import Adam,RMSprop
from keras.utils                        import plot_model
from tensorflow.keras                   import layers, models
from tensorflow.keras.losses            import mae
import sys
import os
import numpy as np
import math
import random, time
from pathlib                        import Path
from PIL                            import Image

import skimage                      as ski
from   skimage.filters              import threshold_otsu
from   skimage                      import io, color
from   skimage.color                import rgb2gray
from   skimage                      import filters
import cv2                          as cv
import matplotlib.pyplot            as plt 
import gc
import glob
from skimage                        import img_as_ubyte
from skimage                        import io
import shutil
tf.keras.backend.clear_session()

# %%
pwd='/home/ppgi/Trabajo/Codigos_generate_data/DLCODES-VER-5/Pression/p_00004.png'

   
def get_img(img_name):
    return ski.io.imread(img_name)

# %%
x=get_img(pwd)

# %%
x.shape
# Out:
# (185, 737, 3)

# %%
plt.imshow(x,cmap='gray')

# %%
w = 256
h = 128

# %%
y =cv.resize(x,(w,h))

# %%
plt.imshow(y,cmap='gray')

# %%
import cv2

img = cv2.imread("/home/ppgi/Trabajo/Codigos_generate_data/DLCODES-VER-5/Pression/p_00004.png")
height, width = img.shape[:2]
aspect_ratio = width / height

# Nuevo alto deseado
new_height = 300
new_width = int(new_height * aspect_ratio)

resized = cv2.resize(img, (new_width, new_height))
#cv2.imwrite("imagen_redimensionada.jpg", resized)

# %%
new_width = 170
height, width = img.shape[:2]
aspect_ratio = height / width 
new_height = int(new_width * aspect_ratio)
y = cv2.resize(img, (new_width, new_height))
plt.imshow(y,cmap='gray')

# %%
y.shape
# Out:
# (42, 170, 3)

# %%
from PIL import Image

img = Image.open("imagen.jpg")

# Ancho deseado
new_width = 100
# Calcular alto manteniendo la proporción
aspect_ratio = img.height / img.width
new_height = int(new_width * aspect_ratio)

# Redimensionar con buena calidad
img_resized = img.resize((new_width, new_height), Image.LANCZOS)
img_resized.save("imagen_redimensionada.jpg")

# %%
plt.imshow(resized)
