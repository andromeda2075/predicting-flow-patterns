# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot            as plt

# %%
path_in='/home/guiomar/Desktop/CODES/predicting-flow-patterns/skelneton_lid_driven_cavity_X.npz'
out_int='/home/guiomar/Desktop/CODES/predicting-flow-patterns/skelneton_lid_driven_cavity_Y.npz'
# 0: Re, 1: SDF 2:Mask
inp=np.load(path_in)
out=np.load(out_int)
X=inp['data']
Y=out['data']
XT = np.transpose(X, (0,2, 3, 1))
YT=np.transpose(Y, (0,2, 3, 1))
#Info
print(XT.shape)
print(YT.shape)
# Out:
# (1000, 256, 256, 3)
# (1000, 256, 256, 4)

# %%
XT_SDF=XT[:,:,:,1]/np.max(XT[:,:,:,1])
XT_bin=XT[:,:,:,2] / 255. 
XT_Re=XT[:,:,:,0]/np.max(XT[:,:,:,0])

# %%
X_in = np.stack([XT_Re, XT_SDF, XT_bin], axis=-1)
